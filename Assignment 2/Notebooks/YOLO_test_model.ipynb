# %% [markdown]
# Based on this tutorial:
#
# https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/

# %% [markdown]
# # Testing the trained yolo model
# This jupiter notebook tests the model I trained using the images in the "test" folder given by the assignment.
#
# When importing the zip file it comes with the model I trained.

# %% [markdown]
# ## Setup

# %% [markdown]
# Only 3 thing needs to be done:
# 1. Make sure that no other sessions is running and run this using GPU.
# 1. Mount the google drive.
# 3. Have the .zip file in the root directory of your google drive or specify the path in the !unzip.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists

# %%
import os.path
from os import path
if path.exists("/content/Bildeanalyse-assignment2-resources") == False:
  # !unzip /mydrive/Bildeanalyse-assignment2-resources.zip -d ./

# %% [markdown]
# ## The code

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies

# %cd /content/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11413, done.
# remote: Total 11413 (delta 0), reused 0 (delta 0), pack-reused 11413
# Receiving objects: 100% (11413/11413), 11.28 MiB | 20.06 MiB/s, done.
# Resolving deltas: 100% (7883/7883), done.
# ...
#      |████████████████████████████████| 11.2 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 73 kB/s
# ...
#      |████████████████████████████████| 4.3 MB 28.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 29.2 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 750.6 MB 11 kB/s
# ...
#      |████████████████████████████████| 21.0 MB 56.1 MB/s
# ...
#      |████████████████████████████████| 899 kB 46.8 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pillow
# ...

# %%
import torch
from IPython.display import Image  # for displaying images

# %%
# !python detect.py --weights /content/Bildeanalyse-assignment2-resources/yolo/model/best.pt --img 416 --conf 0.4 --source /content/Bildeanalyse-assignment2-resources/yolo/Images-yolo-annotated/test/images
# Out:
# ...
# detect: weights=['/content/Bildeanalyse-assignment2-resources/yolo/model/best.pt'], source=/content/Bildeanalyse-assignment2-resources/yolo/Images-yolo-annotated/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-39-g4effd06 torch 1.11.0+cu102 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/50 /content/Bildeanalyse-assignment2-resources/yolo/Images-yolo-annotated/test/images/10_jpg.rf.5f643c84580c9b51c508a24919154c07.jpg: 416x416 1 tattoos, Done. (0.018s)
# ...

# %%
import glob
from IPython.display import Image, display

outputs = glob.glob("/content/yolov5/runs/detect/*")
last_output = outputs[len(outputs)-1] + "/*jpg"

for imageName in glob.glob(last_output):
  display(Image(filename=imageName))
  print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Results when I tested the model
# Time of setting all boundary boxes = 4 seconds.
#
#
# *   Boundary boxes false (false positive) = 5
# *   Boundary boxes reasonable correct = 48
# *   Actual amount of boundary boxes = 60
#
# Accuracy = 48/60 = 0.8 --> 80% Accuracy
